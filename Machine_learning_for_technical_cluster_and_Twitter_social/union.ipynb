# %%
# %sql

select * from decathlon_db_1_csv
union all
select * from ds_dettagli_prodotti_nencini_clean_db_csv
union all
select * from sportler_db_csv
union all 
select * from sp_specialist_abbigl_db_csv
union all 
select * from sp_specialist_scarpe_db_csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </th></tr></thead><tbody><tr><td>decathlon</td><td>8595378</td><td>https://www.decathlon.it/top-donna-comfort-bordeaux-id_8595378.html</td><td>top running donna comfort bordeaux</td><td>maglietta</td><td>top</td><td>kalenji</td><td>abbiamo ideato questo top per il running. il sostegno superiore è adatto per gli impatti frequenti e per tutti gli sport con forti impatti.top con coppe traforate per più traspirabilità . conserva la forma naturale del seno. schiena e spalline regolabili adatte a tutte le corporature, fino alla coppa f.i vantaggi
# sostegno del seno
# sostegno superiore grazie alle coppe fisse avvolgenti: urti ridotti del 44%*
# traspirazione
# coppe traforate, tessuto traforato sulla schiena e tra i seni.
# ...
